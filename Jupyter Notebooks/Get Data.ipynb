# %%
from pathlib import Path
import numpy as np
import os

import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib notebook

from PIL import Image


path = r"C:\Users\khoui\Nutrient_Detection\Food_Data"

# %%
for dirname, _, filenames in os.walk(path):
    count = 0
    for filename in filenames:
        if count > 5: # 5 files
            break
        print(os.path.join(dirname, filename))
        count = count+1
        
#show 5 files from each folder
# Out:
# C:\Users\khoui\Nutrient_Detection\Food_Data\evaluation\0_0.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\evaluation\0_1.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\evaluation\0_10.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\evaluation\0_100.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\evaluation\0_101.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\evaluation\0_102.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\evaluation\0_0.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\evaluation\0_1.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\evaluation\0_10.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\evaluation\0_100.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\evaluation\0_101.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\evaluation\0_102.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\training\0_0.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\training\0_1.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\training\0_10.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\training\0_100.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\training\0_101.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\training\0_102.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\validation\0_0.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\validation\0_1.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\validation\0_10.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\validation\0_100.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\validation\0_101.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\validation\0_102.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\training\0_0.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\training\0_1.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\training\0_10.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\training\0_100.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\training\0_101.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\training\0_102.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\validation\0_0.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\validation\0_1.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\validation\0_10.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\validation\0_100.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\validation\0_101.jpg
# C:\Users\khoui\Nutrient_Detection\Food_Data\validation\0_102.jpg

# %%
#show an image usng matplotlib
img=mpimg.imread(path + "/training/0_101.jpg")
imgplot = plt.imshow(img)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
train_dir = r"C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\training"
test_dir = r"C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\validation"

train_files = [f for f in os.listdir(train_dir) if os.path.isfile(os.path.join(train_dir, f))]
test_files = [f for f in os.listdir(test_dir) if os.path.isfile(os.path.join(test_dir, f))]

# %%
x_train = []
y_train = []
x_test = []
y_test = []

for file in train_files:
    x_train.append(file)
    label= file.find("_")
    y_train.append(int(file[0:label]))
for file in test_files:
    x_test.append(file)
    label= file.find("_")
    y_test.append(int(file[0:label]))

# %%
x_train[1]
# Out:
# '0_1.jpg'

# %%
train_dir
# Out:
# 'C:\\Users\\khoui\\Nutrient_Detection\\Food_Data\\food-11\\training'

# %%
image = x_train[0]
image
# Out:
# '0_0.jpg'

# %%
path
# Out:
# 'C:\\Users\\khoui\\Nutrient_Detection\\Food_Data'

# %%
image = x_train[0]




def display_train_image(image):
    img=mpimg.imread(path + r"\\training\\" + image) 
    
    return img
    #img=mpimg.imread(r"C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\training\0_0.jpg") 

    
display_train_image(image)   
imgplot = plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-cea94f0f6421> in <module>
#      12
#      13 display_train_image(image)
# ---> 14 imgplot = plt.imshow(img)
#      15 plt.show()
#
# AttributeError: 'AxesImage' object has no attribute 'imshow'

# %%
#making plates

def generate_background(image_shape=(64, 64), *, max_difference=0.1):
    ''' Generate a random background of the given shape that is a gray color with a maximum offset of
    `max_difference`.
    
    Parameters
    ----------
    image_shape : Tuple[int, int], optional (default=(64, 64))
        The shape of the background to generate.
        
    max_difference : Real ∈ [0, 1], optional (default=0.1)
        The maximum difference between any two components of the color vector.
    
    Extended Description
    --------------------
    A "perfect" gray can be considered <z, z, z>, where `z` is some color value and the vector represents RGB
    values. For example, black (<0, 0, 0>) and white (<1, 1, 1>) "perfect" grays. An imperfect gray is a color
    value that is very nearly perfect, with some maximum difference between RGB components. For example, the
    color <0.9, 0.85, 0.85> is a near-perfect, with a slight shift toward red. This function generates a random
    background of the provided shape that is a near-perfect gray.
    '''
    if max_difference == 0:
        return np.ones((*image_shape, 3)) * np.random.rand()
    
    color_vector = np.random.rand(3)
    while np.max(color_vector.reshape(1, 3) - color_vector.reshape(3, 1)) > max_difference:
        color_vector = np.random.rand(3) 
    return np.ones((*image_shape, 3)) * color_vector

# %%
generate_background()
# Out:
# array([[[0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         ...,
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674]],
#
#        [[0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         ...,
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674]],
#
#        [[0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         ...,
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674]],
#
#        ...,
#
#        [[0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         ...,
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674]],
#
#        [[0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         ...,
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674]],
#
#        [[0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         ...,
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674],
#         [0.69804494, 0.65423167, 0.60993674]]])

# %%
array = np.array(Image.open(path + "/training/0_101.jpg"))

# %%
array
# Out:
# array([[[103,  36,  17],
#         [102,  35,  16],
#         [ 87,  19,   0],
#         ...,
#         [193, 174, 167],
#         [187, 168, 161],
#         [188, 169, 163]],
#
#        [[107,  40,  21],
#         [105,  38,  19],
#         [ 90,  22,   3],
#         ...,
#         [187, 169, 159],
#         [181, 162, 155],
#         [182, 163, 156]],
#
#        [[107,  40,  21],
#         [104,  37,  18],
#         [ 93,  24,   8],
#         ...,
#         [189, 171, 159],
#         [182, 164, 152],
#         [184, 164, 155]],
#
#        ...,
#
#        [[252, 236, 115],
#         [242, 225, 107],
#         [241, 224, 110],
#         ...,
#         [200, 198, 177],
#         [196, 194, 169],
#         [191, 189, 164]],
#
#        [[249, 235, 104],
#         [246, 231, 102],
#         [245, 229, 107],
#         ...,
#         [194, 192, 167],
#         [196, 192, 165],
#         [193, 189, 160]],
#
#        [[228, 215,  77],
#         [240, 226,  93],
#         [245, 232, 102],
#         ...,
#         [193, 189, 162],
#         [194, 190, 161],
#         [194, 191, 160]]], dtype=uint8)

# %%
train_dir = r"C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\training"
test_dir = r"C:\Users\khoui\Nutrient_Detection\Food_Data\food-11\validation"

picture_list = []
#count = 0
for dirname, _, filenames in os.walk(train_dir):
    for filename in filenames:
        picture = np.array(Image.open(os.path.join(dirname, filename)))
        picture_list.append(picture)
        #count+=1
        
#show 5 files from each folder
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-154-ac7a406c5d53> in <module>
#       6 for dirname, _, filenames in os.walk(train_dir):
#       7     for filename in filenames:
# ----> 8         picture = np.array(Image.open(os.path.join(dirname, filename)))
#       9         picture_list.append(picture)
#      10         #count+=1
#
# ~\Anaconda\envs\Nutrient_Detect\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2876
#    2877     if filename:
# -> 2878         fp = builtins.open(filename, "rb")
#    2879         exclusive_fp = True
#    2880
#
# KeyboardInterrupt:

# %%
len(picture_list)
# Out:
# 7979

# %%
picture = np.array(Image.open()
picture_list.append(picture)
# Out:
# array([[[ 6,  5,  3],
#         [ 6,  5,  3],
#         [ 6,  5,  3],
#         ...,
#         [54, 55, 50],
#         [54, 55, 50],
#         [53, 54, 49]],
#
#        [[ 6,  5,  3],
#         [ 6,  5,  3],
#         [ 6,  5,  3],
#         ...,
#         [54, 55, 50],
#         [54, 55, 50],
#         [54, 55, 50]],
#
#        [[ 6,  5,  3],
#         [ 6,  5,  3],
#         [ 6,  5,  3],
#         ...,
#         [54, 55, 50],
#         [54, 55, 50],
#         [54, 55, 50]],
#
#        ...,
#
#        [[12,  7,  4],
#         [12,  7,  4],
#         [14,  6,  4],
#         ...,
#         [15,  5,  4],
#         [15,  5,  4],
#         [14,  4,  3]],
#
#        [[12,  7,  4],
#         [12,  7,  4],
#         [14,  6,  4],
#         ...,
#         [15,  5,  4],
#         [15,  5,  4],
#         [14,  4,  3]],
#
#        [[12,  7,  4],
#         [12,  7,  4],
#         [14,  6,  4],
#         ...,
#         [14,  6,  4],
#         [14,  6,  4],
#         [13,  5,  3]]], dtype=uint8)
